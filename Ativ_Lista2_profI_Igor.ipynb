# %% [markdown]
#  #Numero positivo ou negativo

# %%
#Numero positivo ou negativo
numero_positivo = float(input("Informe o numero:"))
numero_negativo = float(input("Informe o numero:"))
if numero_positivo > 0:
    print("O numero é positivo")
else:
    print("O numero é negativo")

# %% [markdown]
# #

# %%
idade_usario = int(input("Informe sua idade:"))

if idade_usario >=18:
  print ("Você é maior de idade.")
else :
  print ("Você e menor de idade."

# %%
#3

numero = int(input("Digite um numero:"))

if numero % 2 ==0:
    print("O numero e par")
else:
    print("O numero e impar")

# %%
#4
numero1 = int(input("Digite um numero:"))
numero2 = int(input("Digite outro numero:"))

if numero1 > numero2:
    print("O numero 1 é maior que o numero 2")
else:
    print("O numero 2 é maior que o numero 1")

# %%
#5
#Desconto de compra

valor_compra =float(input("Informe o valor da compra:"))

if valor_compra > 100:
    desconto = valor_compra * 0.10
    valor_final = valor_compra -desconto
    print("O valor da compra:" ,valor_final)
else:
    print (f"O valor da compra é:",valor_compra)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Nova seção

# %%
#6
numero = int(input("Digite um numero :"))

if numero % 5 == 0 :
    print("O numero e multiplo de 5.")
else:
    print("O numero não e multiplo de 5. ")

# %%
#7

nome = input ("Digite seu nome:")
nota_1 = float(input("Digite a primeira nota:"))
nota_2 = float(input("Digite a segunda nota:"))
nota_3 = float(input("Digite a terceira nota:"))
media = (nota_1+ nota_2+nota_3) / 3

if media >= 7 :
   print (f"O aluno {nome} foi aprovado. ")
else:
    print (f"O aluno {nome} foi reprovado. "

# %%
#8

senhaCorreta ='pyton123_EFG'
senha = (input("Informe sua senha para acessar:"))


if senha == senhaCorreta:
   print("Acesso permitido.")
else:
    print("Acesso negado.")

# %%
#9
idade = int(input("Informe sua idade :"))

if idade < 5   and idade  >= 60 :
    print ("Entrada gratuita")
else:
    print("Entrada inteira")

# %%
#9Verifique a nota
Verifique_nota = float(input("Informe sua nota:"))

if Verifique_nota >= 0 and Verifique_nota <= 10:
    print("Total da nota.")
else:
    print("Valor invalido.")
# Out:
# Informe sua nota:11
# Valor invalido.
# Valor invalido.

# %%
#11Catecoria idade.
idade =int(input("Informe sua idade:"))
if idade >= 0 and idade <= 12 :
    print("Criança")
elif idade > 13 and idade <= 17 :
     print("Adolescente")
elif idade >= 18 :
  print("Adulto")
# Out:
# Informe sua idade:14
# Adolescente

# %%
#12 Maior de tres numeros.
numero_1=int(input("Informe o primeiro numero:"))
numero_2=int(input("Informe o segundo numero:"))
numero_3=int(input("Informe o terceiro numero:"))

if numero_1 > numero_2 and numero_1 > numero_3:
    print("O primeiro numero é maior.")
elif numero_2 > numero_1 and numero_2 > numero_3:
    print("O segundo numero é maior.")
elif numero_3 > numero_1 and numero_3 > numero_2:
    print("O terceiro numero é maior.")
# Out:
# Informe o primeiro numero:1
# Informe o segundo numero:2
# Informe o terceiro numero:3
# O terceiro numero é maior.

# %% [markdown]
# #13Divisao segura

# %%
#13 Divisao segura
numero_1 = int(input("Digite o primeiro numero:"))
numero_2 = int(input("Digite o segundo numero:"))

if numero_1 // numero_2:
  print("Divisao realizada.")
else:
  print("A divisão não é possível.")
# Out:
# Digite o primeiro numero:2
# Digite o segundo numero:3
# A divisão não é possível.

# %%
#14 Número dentro do intervalo
numero_entre = int(input("Digite um numero usuário:"))

if numero_entre >= 10 and numero_entre <= 50:
  print("O numero está dentro do intervalo.")
else:
  print("O numero não está dentro do intervalo.")
# Out:
# Digite um numero usuário:25
# O numero está dentro do intervalo.

# %%
#15Aprovado ,recuperação ou reprovado
aluno = input("Informe o nome do aluno:")
nota_1 = float(input("Informe a primeira nota:"))
nota_2 = float(input("Informe a segunda nota:"))
nota_3 = float(input("Informe a terceira nota:"))
media = (nota_1 + nota_2 + nota_3) /3


if media >=7:
  print ("Aprovado")
elif media >= 5 and media < 7:
  print("Recuperação")
elif media < 5:
  print("Reprovado")
# Out:
# Informe o nome do aluno:5
# Informe a primeira nota:5
# Informe a segunda nota:5
# Informe a terceira nota:5
# Recuperação

# %%
#16Calcular IMC
usuario_peso = float(input("Informe seu peso:"))
usuario_altura = float(input("Informe sua altura:"))
IMC = usuario_peso / (usuario_altura * usuario_altura)

if usuario_peso < 18.5 :
  print("Abaixo do peso")
elif usuario_peso >= 18.5 and usuario_peso < 25:
  print("Peso normal")
elif usuario_peso >= 25:
  print("Acima do peso")
# Out:
# Informe seu peso:58
# Informe sua altura:1.58
# Acima do peso

# %%
#17Identificar o triagulo
lado_1 = float(input("Informe o primeiro lado:"))
lado_2 = float(input("Informe o segundo lado:"))
lado_3 = float(input("Informe o terceiro lado:"))

if lado_1 == lado_2 == lado_3 :
 print('Esse é um triâgulo equilátero ')
elif lado_1 == lado_2 or lado_2 == lado_3 or lado_3 == lada_1:
 print('Esse triângulo é isósceles')
else:
 print('Esse triângulo é escaleno')
# Out:
# Informe o primeiro lado:1
# Informe o segundo lado:1
# Informe o terceiro lado:3
# Esse triângulo é isósceles

# %%
#18 login e senha
usuario = input("Informe o nome :")
senha =input("Informe a senha :")

# Verifica se o nome de usuário e a senha estão corretos
if usuario == "admin" and senha == "1234":
    print("Login bem-sucedido!")
else:
    print("Nome de usuário ou senha incorretos.")
# Out:
# Informe o nome :yjhty
# Informe a senha :8884
# Nome de usuário ou senha incorretos.

# %%
#19 verifique maioridade para dirigir
idade_atual = int(input("Informe sua idade:"))

if idade_atual >= 18:
  print("Você pode dirigir")
else:
    anos_faltando = 17 - idade_atual
    print(f"Faltam {anos_faltando} anos para você poder dirigir.")
# Out:
# Informe sua idade:15
# Faltam 2 anos para você poder dirigir.
